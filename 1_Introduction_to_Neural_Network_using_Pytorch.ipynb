# %% [markdown]
# <a href="https://colab.research.google.com/github/Youruler1/Speech-Processing-Lab-Material/blob/main/1_Introduction_to_Neural_Network_using_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load a simple CSV file using Pandas

# %%
import pandas as pd
df=pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Convert the dataframe to tensors

# %%
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_numpy=np.array(df.drop(['Outcome'],axis=1))
y_numpy=np.array(df['Outcome'])
y_numpy=y_numpy.reshape(-1,1)
n_samples, n_features = X_numpy.shape
X = torch.from_numpy(X_numpy.astype(np.float32))
y = torch.from_numpy(y_numpy.astype(np.float32))

# %% [markdown]
# Split the data set into training and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %% [markdown]
# Implement a simple neural network with y=wx+b and subsequent sigmoid function at the output layer

# %%
# 1) Model
# Linear model f = wx + b , sigmoid at the end
class Model(nn.Module):
    def __init__(self, n_input_features):
        super(Model, self).__init__()#already defined in Pytorch.nn, overriding this class
        self.l1 = nn.Linear(n_input_features, 20)
        self.l2=nn.Linear(20,1)


    def forward(self, x):
        x=torch.relu(self.l1(x))
        x = torch.sigmoid(self.l2(x))
        return x

model = Model(n_features)

# %% [markdown]
# Define the loss and optimizer used

# %%
# 2) Loss and optimizer
num_epochs = 1000
learning_rate = 0.001
criterion = nn.BCELoss()#Binary cross entropy
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# Model Training

# %%
# 3) Training loop
for epoch in range(num_epochs):
    # Forward pass and loss
    y_pred = model(X_train)
    loss = criterion(y_pred, y_train)

    # Backward pass and update
    loss.backward()
    optimizer.step()

    # zero grad before new step
    optimizer.zero_grad()

    if (epoch+1) % 10 == 0:
        print(f'epoch: {epoch+1}, loss = {loss.item():.4f}')
# Out:
# epoch: 10, loss = 0.7722
# epoch: 20, loss = 0.7736
# epoch: 30, loss = 0.7731
# epoch: 40, loss = 0.7661
# epoch: 50, loss = 0.7573
# epoch: 60, loss = 0.7468
# epoch: 70, loss = 0.7354
# epoch: 80, loss = 0.7221
# epoch: 90, loss = 0.7100
# epoch: 100, loss = 0.6989
# epoch: 110, loss = 0.6897
# epoch: 120, loss = 0.6805
# epoch: 130, loss = 0.6736
# epoch: 140, loss = 0.6668
# epoch: 150, loss = 0.6609
# epoch: 160, loss = 0.6555
# epoch: 170, loss = 0.6496
# epoch: 180, loss = 0.6437
# epoch: 190, loss = 0.6380
# epoch: 200, loss = 0.6330
# epoch: 210, loss = 0.6281
# epoch: 220, loss = 0.6233
# epoch: 230, loss = 0.6188
# epoch: 240, loss = 0.6150
# epoch: 250, loss = 0.6112
# epoch: 260, loss = 0.6086
# epoch: 270, loss = 0.6059
# epoch: 280, loss = 0.6035
# epoch: 290, loss = 0.6012
# epoch: 300, loss = 0.5989
# epoch: 310, loss = 0.5968
# epoch: 320, loss = 0.5950
# epoch: 330, loss = 0.5934
# epoch: 340, loss = 0.5919
# epoch: 350, loss = 0.5905
# epoch: 360, loss = 0.5894
# ...

# %% [markdown]
# Model Testing

# %%
model.eval()
y_pred = model(X_test)
test_loss = criterion(y_pred, y_test)
print('test loss is {}'.format(test_loss))
# Out:
# test loss is 0.5944665670394897
